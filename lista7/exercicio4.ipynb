# %%
# Import all necessary libraries.
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, ShuffleSplit
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons
from sklearn import tree
from scipy import stats

# %%
# Define the number of examples.
N = 10000
# Create the dataset.
x, y = make_moons(n_samples = N, noise = 0.4, random_state=42)

#b)
x_train, x_test, y_train, y_test = train_test_split (x, y, test_size=0.25, random_state=42)

# %%
print('c)')
idx0 = np.argwhere(y_train == 0)
idx1 = np.argwhere(y_train == 1)

fig = plt.figure(figsize=(5,5))
plt.plot(x_train[idx0,0], x_train[idx0,1], '.', label='Class 0')
plt.plot(x_train[idx1,0], x_train[idx1,1], 'rx', label='Class 1')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.legend()
plt.savefig('distribution_of_classes', dpi=600)
plt.show()
# Out:
# c)

# %%
cv = ShuffleSplit(n_splits=1000, train_size=0.01, random_state=0)

cv.split(x_train)
cv.get_n_splits(x_train)

y_pred_array = []

for pass_index, (i_train, i_test) in enumerate(cv.split(x_train), start=1):
    x_trainN = x_train[i_train]
    y_trainN = y_train[i_train]
    # Create classifier.
    clf = DecisionTreeClassifier(criterion='gini', max_leaf_nodes = 30)
    # Fit the classifier on the training features and labels.
    clf.fit(x_trainN, y_trainN)
    # Use the trained classifier to predict labels for the test features.
    y_pred = clf.predict(x_test)
    y_pred_array.append(y_pred)

    # Calculate the accuracy on the test data 
    print('Accuracy of model is:', accuracy_score(y_test, y_pred)*100, '%')
# Out:
# Accuracy of model is: 81.0 %
# Accuracy of model is: 78.4 %
# Accuracy of model is: 80.92 %
# Accuracy of model is: 75.0 %
# Accuracy of model is: 82.08 %
# Accuracy of model is: 76.88000000000001 %
# Accuracy of model is: 78.32000000000001 %
# Accuracy of model is: 80.08 %
# Accuracy of model is: 77.96 %
# Accuracy of model is: 73.44000000000001 %
# Accuracy of model is: 79.56 %
# Accuracy of model is: 77.08 %
# Accuracy of model is: 77.60000000000001 %
# Accuracy of model is: 79.36 %
# Accuracy of model is: 80.84 %
# Accuracy of model is: 77.48 %
# Accuracy of model is: 80.52 %
# Accuracy of model is: 82.32000000000001 %
# Accuracy of model is: 81.36 %
# Accuracy of model is: 81.96 %
# Accuracy of model is: 79.88 %
# Accuracy of model is: 82.0 %
# Accuracy of model is: 78.60000000000001 %
# Accuracy of model is: 75.44 %
# Accuracy of model is: 80.0 %
# Accuracy of model is: 82.92 %
# Accuracy of model is: 76.52 %
# Accuracy of model is: 78.32000000000001 %
# ...

# %%
best_y_pred = stats.mode(y_pred_array)
print(best_y_pred)
# Calculate the accuracy on the test data 
print('Accuracy of model is:', accuracy_score(y_test, best_y_pred[0][0])*100, '%')
# Out:
# ModeResult(mode=array([[1, 1, 0, ..., 1, 0, 0]], dtype=int64), count=array([[931, 921, 933, ..., 954, 793, 944]]))
# Accuracy of model is: 86.6 %
