# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.datasets import make_circles
from scipy.special import expit
import seaborn as sns
from sklearn.metrics import accuracy_score, roc_curve, auc
from sklearn.metrics import classification_report

# %%
# Create concentric circles.
x, y = make_circles(n_samples=1000, random_state=42, noise=0.1, factor=0.2)

Y = y

y = y/1.0;

y = y.reshape(len(y), 1)

# %%
print('a)')
num_classes = []
for i in y:
    if i not in num_classes:
        num_classes.append(i)
print('There are ' + str(len(num_classes)) + ' classes.')

idx0 = np.argwhere(Y == 0)
idx1 = np.argwhere(Y == 1)

fig = plt.figure(figsize=(5,5))
plt.plot(x[idx0,0], x[idx0,1], '.', label='Class 0')
plt.plot(x[idx1,0], x[idx1,1], 'rx', label='Class 1')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.legend()
plt.show()
# Out:
# a)
# There are 2 classes.

# %% [markdown]
# ## b) No gráfico acima se observa DUAS classes

# %% [markdown]
# ## c) Seria necessária uma frontera de decisão NÃO LINEAR

# %%
def error_function(x, a, y):    
    h = expit(x.dot(a))
    error = -(1/len(y))*np.sum( y.T.dot(np.log(h)) + (1-y).T.dot(np.log((1-h) )) )
    return error

def classifier(x, a):
    h = expit(x.dot(a))
    c = np.zeros((len(h), 1))
    for i in range(0, len(h)):
        if(h[i] >= 0.5):
            c[i,0]=1.0
    return c

def predict_prob(x, a):
    h1 = expit(x.dot(a))
    h0 = 1 - h1
    h = np.c_[h0, h1]
    return h

# %%
# Split array into random train and test subsets.
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=23)

x_train = np.c_[np.ones((len(y_train), 1)), x_train]

x_test = np.c_[np.ones((len(y_test), 1)), x_test]

# %%
# Batch gradient descent solution.

# learning rate.
alpha = 4.0
# Maximum number of iterations.
n_iterations = 1000

# Random initialization of parameters.
a = np.random.randn(x_train.shape[1],1)

# Create array for storing error values.
Jgd = np.zeros(n_iterations+1)
Jgd_v = np.zeros(n_iterations+1)

# Calculate initial error.
Jgd[0] = error_function(x_train, a, y_train)
Jgd_v[0] = error_function(x_test, a, y_test)

# Batch gradient-descent loop.
minimum_val_error = float("inf")
iteration = 0
error = 1
while iteration < n_iterations:
    gradients = -1/len(y_train)*x_train.T.dot(y_train - expit(x_train.dot(a)) )
    a = a - alpha * gradients
    Jgd[iteration+1] = error_function(x_train, a, y_train)
    Jgd_v[iteration+1] = error_function(x_test, a, y_test)
    error = np.abs(Jgd[iteration+1] - Jgd[iteration])
    # Store weights for the smallest error ever.
    if(Jgd_v[iteration+1] < minimum_val_error):
        minimum_val_error = Jgd_v[iteration+1]
        a_min = a        
    iteration = iteration + 1

# %%
print('d)')
fig = plt.figure(figsize=(7,7))
plt.plot(np.arange(0, iteration - 980), Jgd[0:iteration - 980], label='treinamento')
plt.plot(np.arange(0, iteration - 980), Jgd_v[0:iteration - 980], label='validação')
#plt.xlim((0, iteration))
plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel('$J_e$')
plt.title('Error vs. Iteration number')
plt.legend()
plt.show()
# Out:
# d)

# %%
print('f)')
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = x[:, 0].min() - .5, x[:, 0].max() + .5
y_min, y_max = x[:, 1].min() - .5, x[:, 1].max() + .5
h = .02  # step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

Z = classifier(np.c_[np.ones((len(xx.ravel()), 1)), xx.ravel(), yy.ravel()], a_min)

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(5, 5))
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

# Plot also the training points
plt.scatter(x[:, 0], x[:, 1], c=Y, edgecolors='k', cmap=plt.cm.Paired)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# f)

# %%
print('e)')
y_pred_class = classifier(x_test, a_min)

# Plot the confusion matrix
fig = plt.figure(figsize=(5,5))
mat = confusion_matrix(y_test, y_pred_class)
sns.set()
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False, xticklabels=['0','1'], yticklabels=['0','1'], cmap="Blues")
plt.xlabel('true label')
plt.ylabel('predicted label')
plt.show()
# Out:
# e)

# %%
print('g)')
# Getting the probabilities for each class.
y_prob = predict_prob(x_test, a_min)
# Calculating ROC curve and ROC AUC.
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob[:, 1])
roc_auc = auc(false_positive_rate, true_positive_rate)
# Plotting ROC curve.
lw = 2
plt.plot(false_positive_rate, true_positive_rate, color='blue', lw=lw, label='ROC curve (area = {:.4f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='red', lw=lw, linestyle='--', label='Random classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.legend(loc="lower right")
plt.show()
# Out:
# g)

# %%
print('h)')
print(classification_report(y_test, y_pred_class))
# Out:
# h)
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.62      0.45       116
#          1.0       0.00      0.00      0.00       134
#
#     accuracy                           0.29       250
#    macro avg       0.17      0.31      0.22       250
# weighted avg       0.16      0.29      0.21       250

# %% [markdown]
# ## i)

# %%
x_train1 = np.c_[x_train, x_train[:,1]**2]
x_train1 = np.c_[x_train1, x_train[:,2]**2]

x_test1 = np.c_[x_test, x_test[:,1]**2]
x_test1 = np.c_[x_test1, x_test[:,2]**2]

# %%
# Batch gradient descent solution.

# learning rate.
alpha = 10.0
# Maximum number of iterations.
n_iterations = 1000

# Random initialization of parameters.
a = np.random.randn(x_train1.shape[1],1)

# Create array for storing error values.
Jgd = np.zeros(n_iterations+1)
Jgd_v = np.zeros(n_iterations+1)

# Calculate initial error.
Jgd[0] = error_function(x_train1, a, y_train)
Jgd_v[0] = error_function(x_test1, a, y_test)

# Batch gradient-descent loop.
minimum_val_error = float("inf")
iteration = 0
error = 1
while iteration < n_iterations:
    gradients = -1/len(y_train)*x_train1.T.dot(y_train - expit(x_train1.dot(a)))
    a = a - alpha * gradients
    Jgd[iteration+1] = error_function(x_train1, a, y_train)
    Jgd_v[iteration+1] = error_function(x_test1, a, y_test)
    error = np.abs(Jgd[iteration+1] - Jgd[iteration])
    # Store weights for the smallest error ever.
    if(Jgd_v[iteration+1] < minimum_val_error):
        minimum_val_error = Jgd_v[iteration+1]
        a_min = a        
    iteration = iteration + 1

# %%
print('d)')
fig = plt.figure(figsize=(7,7))
plt.plot(np.arange(0, iteration), Jgd[0:iteration], label='treinamento')
plt.plot(np.arange(0, iteration), Jgd_v[0:iteration], label='validação')
#plt.xlim((0, iteration))
plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel('$J_e$')
plt.title('Error vs. Iteration number')
plt.legend()
plt.show()
# Out:
# d)

# %%
print('e)')
y_pred_class1 = classifier(x_test1, a_min)

# Plot the confusion matrix
fig = plt.figure(figsize=(5,5))
mat = confusion_matrix(y_test, y_pred_class1)
sns.set()
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False, xticklabels=['0','1'], yticklabels=['0','1'], cmap="Blues")
plt.xlabel('true label')
plt.ylabel('predicted label')
plt.show()
# Out:
# e)

# %%
print('f)')
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min1, x_max1 = x[:, 0].min() - .5, x[:, 0].max() + .5
y_min1, y_max1 = x[:, 1].min() - .5, x[:, 1].max() + .5
h = .02  # step size in the mesh
xx1, yy1 = np.meshgrid(np.arange(x_min1, x_max1, h), np.arange(y_min1, y_max1, h))

Z1 = classifier(np.c_[np.ones((len(xx1.ravel()), 1)), xx1.ravel(), yy1.ravel(), xx1.ravel()**2, yy1.ravel()**2], a_min)

# Put the result into a color plot
Z1 = Z1.reshape(xx1.shape)
plt.figure(1, figsize=(5, 5))
plt.pcolormesh(xx1, yy1, Z1, cmap=plt.cm.Paired)

# Plot also the training points
plt.scatter(x[:, 0], x[:, 1], c=Y, edgecolors='k', cmap=plt.cm.Paired)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# f)

# %%
print('g)')
# Getting the probabilities for each class.
y_prob1 = predict_prob(x_test1, a_min)
# Calculating ROC curve and ROC AUC.
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob1[:, 1])
roc_auc = auc(false_positive_rate, true_positive_rate)
# Plotting ROC curve.
lw = 2
plt.plot(false_positive_rate, true_positive_rate, color='blue', lw=lw, label='ROC curve (area = {:.4f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='red', lw=lw, linestyle='--', label='Random classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.legend(loc="lower right")
plt.show()
# Out:
# g)

# %%
print('h)')
print(classification_report(y_test, y_pred_class1))
# Out:
# h)
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       116
#          1.0       1.00      1.00      1.00       134
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250

# %% [markdown]
# ## j) A performance do classificador entre as duas funções hipóteses é diferente. A segunda hipóteses confiere uma precisão perfeita pois está baseada em uma função polinomial. A primeira hipóteses é linear e portanto confiere uma precisão muito baixa pois não pode representar a fronteira de decisão circular neste caso.
