# %%
from matplotlib import pyplot as plt
import cv2

img = cv2.imread('C:/Anabel/inatel 2020/TP555- IA and ML/5ta aula/exercicio1.png')
img_plot = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

fig = plt.figure(figsize=(10, 10))
plt.imshow(img_plot)
plt.title('exercício1')
plt.show()

print('-As funções lógicas OR e AND podem ser classificadas com um classificador linear.')
print('-No caso da função lógica XOR pode ser classificada com classificador polinomial, pois é preciso de fronteiras de decisão não-lineares.')
# Out:
# -As funções lógicas OR e AND podem ser classificadas com um classificador linear.
# -No caso da função lógica XOR pode ser classificada com classificador polinomial, pois é preciso de fronteiras de decisão não-lineares.
